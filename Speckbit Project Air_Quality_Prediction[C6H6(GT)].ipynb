# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as snc

# %%
air_quality = pd.read_csv("AirQualityUCl.csv", sep=";", decimal=",")

# %% [markdown]
# We will use the AirQualityUCI.csv file as our dataset. It is a ';' seperated file so we'll specify it as a parameter for the read_csv function.

# %%
air_quality.dropna(axis=0, how= 'all', inplace=True)
air_quality.dropna(axis=1, inplace=True)

# %% [markdown]
# The data contains null values. So we drop those rows and columns containing null values.

# %%
air_quality.replace(to_replace= -200, value= np.NaN, inplace= True)
air_quality.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# 4  11.2  59.6  0.7888

# %% [markdown]
# The data contains missing values which are represented by the value -200 so we'll replace these values by the null value(np.NaN).

# %%
air_quality.fillna(air_quality.mean(), inplace= True)

# %% [markdown]
# Here we'll replace these null values by the mean value of the row.

# %%
snc.heatmap(air_quality.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
air_quality.loc[:,'Date']=air_quality['Date']
air_quality.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# 4  11.2  59.6  0.7888

# %% [markdown]
# For "Date", convert string values to datetime data type, and store them in list "Date"

# %%
from datetime import datetime
Date= []
for i in air_quality['Date']:
    Date.append(datetime.strptime(i,'%d/%m/%Y'))
air_quality.dtypes
# Out:
# Date              object
# Time              object
# CO(GT)           float64
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)         float64
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                float64
# RH               float64
# AH               float64
# dtype: object

# %%
date=pd.Series(Date)
air_quality['Date']=pd.to_numeric(date)

# %% [markdown]
# Convert Date list to series, and use it as the index of data

# %%
air_quality['Date']=air_quality['Date'].astype(float)
air_quality.dtypes
# Out:
# Date             float64
# Time              object
# CO(GT)           float64
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)         float64
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                float64
# RH               float64
# AH               float64
# dtype: object

# %% [markdown]
# Displaying the datatypes of all the features.

# %%
air_quality.head()
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  1.078877e+18  18.00.00     2.6       1360.0     150.0      11.9
# 1  1.078877e+18  19.00.00     2.0       1292.0     112.0       9.4
# 2  1.078877e+18  20.00.00     2.2       1402.0      88.0       9.0
# 3  1.078877e+18  21.00.00     2.2       1376.0      80.0       9.2
# 4  1.078877e+18  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# 4  11.2  59.6  0.7888

# %%
air_quality.loc[:,'Time']=air_quality['Time']

# %% [markdown]
# For "Time", convert string values to datetime data type, and store them in list "Time"

# %%
from datetime import datetime
Time= []
for i in air_quality['Time']:
    Time.append(datetime.strptime(i,'%H.%M.%S'))
air_quality.dtypes
# Out:
# Date             float64
# Time              object
# CO(GT)           float64
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)         float64
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                float64
# RH               float64
# AH               float64
# dtype: object

# %%
time=pd.Series(Time)
air_quality['Time']=pd.to_numeric(time)

# %% [markdown]
# Convert Time list to series, and use it as the index of data

# %%
air_quality['Time']=air_quality['Time'].astype(float)
air_quality.dtypes
# Out:
# Date             float64
# Time             float64
# CO(GT)           float64
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)         float64
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                float64
# RH               float64
# AH               float64
# dtype: object

# %% [markdown]
# Displaying the datatypes of all the features.

# %%
air_quality
# Out:
#               Date          Time   CO(GT)  PT08.S1(CO)    NMHC(GT)  C6H6(GT)  \
# 0     1.078877e+18 -2.208924e+18  2.60000       1360.0  150.000000      11.9
# 1     1.078877e+18 -2.208920e+18  2.00000       1292.0  112.000000       9.4
# 2     1.078877e+18 -2.208917e+18  2.20000       1402.0   88.000000       9.0
# 27         1285.0   9.1  64.0  0.7419
# 28          821.0   8.2  63.4  0.6905
# 29          552.0   8.2  60.8  0.6657
# ...           ...   ...   ...     ...
# 9327        831.0  17.8  30.7  0.6205
# 9328        613.0  21.1  23.7  0.5875
# 9329        640.0  24.0  19.3  0.5673
# 9330        631.0  26.5  16.4  0.5594
# 9331        456.0  28.7  13.7  0.5302
# 9332        450.0  28.5  13.1  0.5002
# 9333        516.0  30.0  11.1  0.4624
# 9334        548.0  29.4  10.4  0.4192
# 9335        603.0  28.9   9.9  0.3866
# 9336        597.0  22.8  21.7  0.5945
# 9337       1167.0  19.9  33.0  0.7608
# 9338       1372.0  17.5  40.7  0.8073
# 9339       1042.0  16.4  46.6  0.8642
# 9340       1055.0  15.5  49.0  0.8579
# 9341       1049.0  14.3  52.5  0.8497
# 9342        816.0  14.2  51.4  0.8275
# 9343        598.0  13.8  51.2  0.8058
# 9344        573.0  12.1  56.3  0.7927
# 9345        549.0  11.3  58.9  0.7888
# 9346        489.0  11.8  56.0  0.7743
# 9347        578.0  10.4  59.9  0.7550
# 9348        905.0   9.5  63.1  0.7531
# 9349       1457.0   9.7  61.9  0.7446
# 9350       1705.0  13.5  48.9  0.7553
# 9351       1583.0  18.2  36.3  0.7487
# 9352       1729.0  21.9  29.3  0.7568
# 9353       1269.0  24.3  23.7  0.7119
# 9354       1092.0  26.9  18.3  0.6406
# 9355        770.0  28.3  13.5  0.5139
# 9356        816.0  28.5  13.1  0.5028
#
# [9357 rows x 15 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
num = air_quality.keys()
scaler = MinMaxScaler()
scaler.fit(air_quality[num])
air_quality[num] = scaler.transform(air_quality[num])

# %% [markdown]
# Here feature scaling is done to transform raw data into a standardized dataset so that so that they fall in a specific range of values. MinMaxScaler is used which transforms the data in the range between 0 and 1.

# %%
air_quality.head()
# Out:
#            Date          Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  1.078877e+18 -2.208924e+18     2.6       1360.0     150.0      11.9
# 1  1.078877e+18 -2.208920e+18     2.0       1292.0     112.0       9.4
# 2  1.078877e+18 -2.208917e+18     2.2       1402.0      88.0       9.0
# 3  1.078877e+18 -2.208913e+18     2.2       1376.0      80.0       9.2
# 4  1.078877e+18 -2.208910e+18     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# 4  11.2  59.6  0.7888

# %%
snc.pairplot(air_quality[["Date","Time","CO(GT)","PT08.S1(CO)","NMHC(GT)","C6H6(GT)","PT08.S2(NMHC)","NOx(GT)","PT08.S3(NOx)","NO2(GT)","PT08.S4(NO2)","PT08.S5(O3)"]],diag_kind = "auto")

# %% [markdown]
# Visualizing the data using pair plots to determine whether the data is linear.

# %%
features=air_quality

# %%
features=features.drop('C6H6(GT)',axis=1)

# %% [markdown]
# Computing the features.

# %%
target=air_quality['C6H6(GT)']

# %% [markdown]
# Computing the target by selecting the target as C6H6(GT) because C6H6(GT) is the main pollutant causing air pollution.

# %%
air_quality2=air_quality.corr('pearson')
air_quality2
# Out:
#                    Date      Time    CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# Date           1.000000 -0.003249  0.041514    -0.003232  0.008010 -0.064007
# Time          -0.003249  1.000000  0.323944     0.321097  0.102758  0.336890
# CO(GT)         0.041514  0.323944  1.000000     0.773394  0.289975  0.812361
# PT08.S1(CO)   -0.003232  0.321097  0.773394     1.000000  0.278282  0.883795
# NMHC(GT)       0.008010  0.102758  0.289975     0.278282  1.000000  0.281928
# C6H6(GT)      -0.064007  0.336890  0.812361     0.883795  0.281928  1.000000
# PT08.S2(NMHC) -0.083633  0.380964  0.795578     0.892964  0.279761  0.981950
# NOx(GT)        0.401280  0.200493  0.762273     0.615941  0.098180  0.616801
# PT08.S3(NOx)  -0.251775 -0.316828 -0.613877    -0.771938 -0.261997 -0.735744
# NO2(GT)        0.349315  0.327673  0.646349     0.562843  0.156510  0.535919
# PT08.S4(NO2)  -0.517637  0.216572  0.558232     0.682881  0.232979  0.765731
# PT08.S5(O3)    0.103508  0.239880  0.759027     0.899324  0.240592  0.865689
# T             -0.450032  0.202272  0.020257     0.048627  0.066782  0.198956
# RH             0.212245 -0.289543  0.043198     0.114606 -0.052784 -0.061681
# AH            -0.310146 -0.018233  0.043274     0.135324  0.037173  0.167972
#
#                PT08.S2(NMHC)   NOx(GT)  PT08.S3(NOx)   NO2(GT)  PT08.S4(NO2)  \
# Date               -0.083633  0.401280     -0.251775  0.349315     -0.517637
# Time                0.380964  0.200493     -0.316828  0.327673      0.216572
# CO(GT)              0.795578  0.762273     -0.613877  0.646349      0.558232
# PT08.S1(CO)         0.892964  0.615941     -0.771938  0.562843      0.682881
# NMHC(GT)            0.279761  0.098180     -0.261997  0.156510      0.232979
# C6H6(GT)            0.981950  0.616801     -0.735744  0.535919      0.765731
# PT08.S2(NMHC)       1.000000  0.601773     -0.796703  0.561180      0.777254
# NOx(GT)             0.601773  1.000000     -0.563270  0.763074      0.205485
# PT08.S3(NOx)       -0.796703 -0.563270      1.000000 -0.569479     -0.538468
# NO2(GT)             0.561180  0.763074     -0.569479  1.000000      0.140655
# PT08.S4(NO2)        0.777254  0.205485     -0.538468  0.140655      1.000000
# PT08.S5(O3)         0.880578  0.688205     -0.796569  0.629443      0.591144
# T                   0.241373 -0.235636     -0.145112 -0.165466      0.561270
# RH                 -0.090380  0.192587     -0.056740 -0.080569     -0.032188
# AH                  0.186933 -0.126868     -0.232017 -0.291392      0.629641
#
#                PT08.S5(O3)         T        RH        AH
# Date              0.103508 -0.450032  0.212245 -0.310146
# Time              0.239880  0.202272 -0.289543 -0.018233
# CO(GT)            0.759027  0.020257  0.043198  0.043274
# PT08.S1(CO)       0.899324  0.048627  0.114606  0.135324
# NMHC(GT)          0.240592  0.066782 -0.052784  0.037173
# C6H6(GT)          0.865689  0.198956 -0.061681  0.167972
# PT08.S2(NMHC)     0.880578  0.241373 -0.090380  0.186933
# NOx(GT)           0.688205 -0.235636  0.192587 -0.126868
# PT08.S3(NOx)     -0.796569 -0.145112 -0.056740 -0.232017
# NO2(GT)           0.629443 -0.165466 -0.080569 -0.291392
# PT08.S4(NO2)      0.591144  0.561270 -0.032188  0.629641
# PT08.S5(O3)       1.000000 -0.027172  0.124956  0.070751
# T                -0.027172  1.000000 -0.578621  0.656397
# RH                0.124956 -0.578621  1.000000  0.167971
# AH                0.070751  0.656397  0.167971  1.000000

# %% [markdown]
# Using the Pearson correlation to find out what features contribute most to predicting our target.

# %%
abs(air_quality2['C6H6(GT)']).sort_values(ascending=False)
# Out:
# C6H6(GT)         1.000000
# PT08.S2(NMHC)    0.981950
# PT08.S1(CO)      0.883795
# PT08.S5(O3)      0.865689
# CO(GT)           0.812361
# PT08.S4(NO2)     0.765731
# PT08.S3(NOx)     0.735744
# NOx(GT)          0.616801
# NO2(GT)          0.535919
# Time             0.336890
# NMHC(GT)         0.281928
# T                0.198956
# AH               0.167972
# Date             0.064007
# RH               0.061681
# Name: C6H6(GT), dtype: float64

# %%
air_quality['C6H6(GT)'].value_counts().plot(kind='bar', color='lightblue', figsize=(50,10))

# %% [markdown]
# Plotting the counts of unique values of the target.

# %%
features=features.drop('Date',axis=1)
features=features.drop('Time',axis=1)
features=features.drop('T',axis=1)
features=features.drop('RH',axis=1)
features=features.drop('AH',axis=1)
features=features.drop('NMHC(GT)',axis=1)
features.head()
# Out:
#    CO(GT)  PT08.S1(CO)  PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  \
# 0     2.6       1360.0         1046.0    166.0        1056.0    113.0
# 1     2.0       1292.0          955.0    103.0        1174.0     92.0
# 2     2.2       1402.0          939.0    131.0        1140.0    114.0
# 3     2.2       1376.0          948.0    172.0        1092.0    122.0
# 4     1.6       1272.0          836.0    131.0        1205.0    116.0
#
#    PT08.S4(NO2)  PT08.S5(O3)
# 0        1692.0       1268.0
# 1        1559.0        972.0
# 2        1555.0       1074.0
# 3        1584.0       1203.0
# 4        1490.0       1110.0

# %% [markdown]
# Dropping the features that are having low corelation values and computing the final features for better accuracy.

# %%
features=features.values
target=target.values

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Splitting the features and target into random train and test subsets using train_test_split()

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression(normalize=True)
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=True)

# %% [markdown]
# Fitting the linear model.

# %%
print("Predicted values:", regressor.predict(X_test))
y_pred = regressor.predict(X_test)
y_pred.shape
# Out:
# Predicted values: [ 9.46701324  3.92113833  6.69630538 ...  8.97324219 10.59987959
#   2.34271297]
# (2808,)

# %% [raw]
# Predict using the linear model.

# %%
print("R^2 score for liner regression: ", regressor.score(X_test, y_test))
# Out:
# R^2 score for liner regression:  0.9752107536307779

# %% [markdown]
# Computing the R^2 score for linear regression.

# %%
plt.scatter(y_test,y_pred,color='black')
plt.show()

# %% [markdown]
# Plotting the graph for linear regression.

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
a=Lasso(alpha=0.5)
a.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %% [markdown]
# Fitting the lasso regression model.

# %%
print("R^2 on train set : {}".format(a.score(X_train, y_train)))
# Out:
# R^2 on train set : 0.9741855374334486

# %% [markdown]
# R^2 score on train set for lasso regression.

# %%
print("R^2 on test set : {}".format(a.score(X_test, y_test)))
# Out:
# R^2 on test set : 0.9746356180681316

# %% [markdown]
# R^2 score on test set for lasso regression.

# %% [markdown]
# # Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor()
dtr.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %% [markdown]
# Fitting the decision tree regression model.

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(dtr.score(X_train, y_train)))
# Out:
# Coefficient of determination R^2 <-- on train set: 1.0

# %% [markdown]
# R^2 score on train set for decision tree regression.

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(dtr.score(X_test, y_test)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.9986895960582448

# %% [markdown]
# R^2 score on test set for decision tree regression.
